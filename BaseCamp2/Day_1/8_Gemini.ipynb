# %% [markdown]
# ### Gemini Usage for LLM ###
# **Library Need**
# To use the APIs provided by the Geimi platform, the library 'Google GenAI' is required.
# Ensure to have performed 'pip install google-genai dotenv'
# The API key from your Google AI account would be required to execute this code

# %%
# Import required class from Google
from google import genai
from google.genai import types
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
client = genai.Client()

# Client = genai.Client (api_key='Your API Key')

# %% [markdown]
# **Invoke for chat Completion**
# >We try Gemini to get response from LLM
# >Note the differece in terms of API

# %%
response = client.models.generate_content(
                model="gemini-2.5-flash", 
                contents="I am not a hardware specialist. Explain GPU vs TPU to me."
            )
print(response.text)
# Out:
# Okay, let's break down GPU vs. TPU without getting bogged down in technical jargon. Think of it like this:
#
# Imagine you need to do a lot of **math problems**. Not just any math, but specific kinds of math that involve multiplying many numbers together at the same time, over and over again. This is the core of what AI (Artificial Intelligence) and Machine Learning (ML) do.
#
# ---
#
# ## 1. GPU (Graphics Processing Unit)
#
# *   **What it is:** Originally designed to make video games look incredibly realistic and smooth. It's really good at drawing thousands of pixels on your screen simultaneously, calculating how light bounces, how textures look, etc.
# *   **How it works (for our analogy):** Imagine you have a **team of many, many super-fast, general-purpose calculators**. Each calculator is pretty good, and there are tons of them. When you need to do a lot of the same simple math problems all at once (like calculating what color each pixel should be), you can give each calculator a small piece of the problem, and they all work in parallel.
# *   **Why it's used for AI:** AI training also involves a massive amount of parallel math (multiplying big grids of numbers called "matrices" or "tensors"). Developers realized, "Hey, these GPU things are designed to do tons of parallel math for graphics, they could be really good at the parallel math for AI too!" And they were right.
# *   **Think of it like:** A **super-talented, multi-tool chef**. They can cook *anything* – gourmet meals, baked goods, snacks – and they're really good at tasks that involve doing the same thing many times (like chopping 100 onions for a big soup).
#
# **Pros for AI:**
# *   **Versatile:** Can do many things beyond just AI (graphics, scientific simulations, general computing tasks).
# *   **Widely Available:** You can find them in gaming PCs, workstations, and cloud computing services from many different companies.
# *   **Powerful:** Still incredibly good at AI tasks.
#
# **Cons for AI:**
# *   **Not *perfectly* optimized:** Because they're general-purpose, some parts of their design aren't strictly necessary for AI, meaning they might use a bit more power or not be *the absolute fastest* for pure AI math compared to something specialized.
#
# ---
#
# ## 2. TPU (Tensor Processing Unit)
#
# *   **What it is:** This is a chip developed specifically by **Google**, *only* for AI and Machine Learning tasks. "Tensor" refers to "TensorFlow," Google's popular AI framework, and also to the multi-dimensional data structures (like those big grids of numbers) that AI models work with.
# *   **How it works (for our analogy):** Imagine you have a **highly specialized robot chef**. This robot doesn't know how to cook anything *except* baking cookies. But when it comes to baking cookies, it's unbelievably fast, efficient, and makes perfect cookies every single time. It's built from the ground up for that *one specific task*.
# *   **Why it was created:** Google uses AI for everything – search results, translation, self-driving cars, email filters. They were using so many GPUs that they thought, "What if we built a chip that was *only* designed for the specific math AI needs, and nothing else?" This allowed them to make it incredibly efficient and fast for those tasks.
# *   **Think of it like:** A **highly specialized robot chef *only* for baking cookies**. It can't cook anything else, but for baking cookies, it's unbeatable in speed and efficiency.
#
# **Pros for AI:**
# *   **Hyper-efficient for AI:** Designed from the ground up to be incredibly fast and energy-efficient for AI math.
# *   **Faster for specific tasks:** For *certain types* of AI training and inference, TPUs can be significantly faster than GPUs.
# *   **Cost-effective (in the cloud):** Because they are so efficient, they can often be a cheaper option per computation when accessed through Google's cloud services.
#
# **Cons for AI:**
# *   **Less Versatile:** Can't do general graphics, gaming, or other computing tasks. It's a "one-trick pony," but that trick is AI.
# *   **Limited Availability:** Primarily available through **Google Cloud**. You can't just buy a TPU chip and put it in your home computer like you can with a GPU.
#
# ---
#
# ## The Key Difference in a Nutshell
#
# *   **GPU:** A **powerful, versatile multi-tool** that happens to be excellent at AI because AI tasks share similarities with its original purpose (graphics). It's a great *generalist*.
# *   **TPU:** A **highly specialized, purpose-built machine** designed from the ground up for *only* AI tasks. It's a top-tier *specialist* for that one thing.
#
# **When you'd use which:**
#
# *   If you're **building a new AI model from scratch**, or doing diverse computing tasks, a **GPU** is a great, flexible choice.
# *   If you're **running Google's own AI models**, or want the absolute most efficient way to run *specific types* of AI workloads within the Google Cloud ecosystem, a **TPU** might be faster and more cost-effective.

# %%
# There is a specific instruction given 
Instruction = "Continue the statement and make it 50 words"
Statement  = "When we get to see new AI models every week ..."
# Statement  = "Though we get to see new AI models every week ..."
# Statement  = "RAG is useful in scenarios ..."

# Invoke multiple times ...
# ?? What do we expect 
for i in range (3):
    
    response = client.models.generate_content(
                    model="gemini-2.5-flash-lite",
                    # model="gemini-flash-lite-latest",
                    config =types.GenerateContentConfig(
                                system_instruction=Instruction,),
                    contents =Statement
    )

    print(response.text)
# Out:
# When we get to see new AI models every week, it's both exhilarating and slightly overwhelming. Each release pushes the boundaries of what's possible, offering enhanced capabilities and novel applications. This rapid pace necessitates continuous learning and adaptation for developers and users alike, ensuring we can harness the ever-evolving power of AI.
# When we get to see new AI models every week, it's a thrilling sign of rapid innovation and intense competition in the field. This accelerated pace democratizes access to powerful tools, fostering exciting new applications and research possibilities across industries. However, it also raises critical questions about ethical development, responsible deployment, and the societal impact of such swift advancements.
# When we get to see new AI models every week, it's clear we're in an era of unprecedented technological acceleration. This rapid evolution brings incredible potential for innovation across industries, promising to revolutionize everything from healthcare and education to entertainment and scientific discovery. However, it also raises critical questions about ethics, job displacement, and responsible development.
